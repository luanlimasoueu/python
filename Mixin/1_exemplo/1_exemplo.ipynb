# %%
class Shape:
    def __init__( self, x, y):
        self.x = x
        self.y = y

    def serealize ( self):
        print(",".join( [f"{k} = {v}" for k, v in self.__dict__.items()]))

class Rectangle():
    pass

class Circle():
    pass
