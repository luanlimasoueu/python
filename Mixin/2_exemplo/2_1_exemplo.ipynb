# %%
class TelMixin:
    def telfunc(self):
        print("I can make calls")


class SMSMixin:
    def smsfunc(self):
        print("I can send text messages")


class SongMixin:
    def songfunc(self):
        print("I can play music")


class Intercom(TelMixin):
    def __init__(self, sn):
        self.sn = sn

    def telfunc(self):
        print("Intercom{} call".format(self.sn))


class Phone(TelMixin, SMSMixin, SongMixin):
    def __init__(self, sn):
        self.sn = sn


class Ipod(SongMixin):
    def __init__(self, sn):
        self.sn = sn


def testTelfunc(o):
    o.telfunc()


d = Intercom("moto")
p = Phone("huawei")
ipod = Ipod("apple")
testTelfunc(d)
testTelfunc(p)
testTelfunc(ipod)
# Out:
# Intercommoto call
# I can make calls
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 43
#      41 testTelfunc(d)
#      42 testTelfunc(p)
# ---> 43 testTelfunc(ipod)
#
# Cell In[1], line 35, in testTelfunc(o)
#      34 def testTelfunc(o):
# ---> 35     o.telfunc()
#
# AttributeError: 'Ipod' object has no attribute 'telfunc'
