# %%
import asyncio
import pandas as pd

async def processar_dataframe(df):
    resultados = []
    for _, row in df.iterrows():
        #await asyncio.sleep(0.5)  # Simula um processamento assíncrono
        resultados.append(row.to_dict())
    return resultados

async def mostrar_resultado(df):
    resultados = await processar_dataframe(df)
    for resultado in resultados:
        print(resultado)

# Criando um DataFrame de exemplo
dados = {'Nome': ['Alice', 'Bob', 'Carlos'], 'Idade': [25, 30, 22]}
df = pd.DataFrame(dados)

# Ajuste para rodar dentro de um ambiente assíncrono
async def main():
    await mostrar_resultado(df)

# Verifica se já existe um loop de eventos rodando
if __name__ == "__main__":
    try:
        asyncio.run(main())
    except RuntimeError:  # Se já houver um loop rodando
        loop = asyncio.get_event_loop()
        loop.create_task(main())
# Out:
# C:\Users\Luan Lima\AppData\Local\Temp\ipykernel_23192\2032142872.py:30: RuntimeWarning: coroutine 'main' was never awaited
#   loop.create_task(main())
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# {'Nome': 'Alice', 'Idade': 25}
# {'Nome': 'Bob', 'Idade': 30}
# {'Nome': 'Carlos', 'Idade': 22}

# %%
import asyncio
import pandas as pd

async def processar_linha(row, sem):
    async with sem:  # Limita o número de tarefas simultâneas
        await asyncio.sleep(0.5)  # Simula um processamento assíncrono
        return row.to_dict()

async def processar_dataframe(df, limite):
    sem = asyncio.Semaphore(limite)  # Define o limite de concorrência
    tarefas = [processar_linha(row, sem) for _, row in df.iterrows()]
    return await asyncio.gather(*tarefas)

async def mostrar_resultado(df, limite=2):
    resultados = await processar_dataframe(df, limite)
    for resultado in resultados:
        print(resultado)

# Criando um DataFrame de exemplo
dados = {'Nome': ['Alice', 'Bob', 'Carlos'], 'Idade': [25, 30, 22]}
df = pd.DataFrame(dados)

# Ajuste para rodar dentro de um ambiente assíncrono
async def main():
    await mostrar_resultado(df, limite=2)

# Verifica se já existe um loop de eventos rodando
if __name__ == "__main__":
    try:
        asyncio.run(main())
    except RuntimeError:  # Se já houver um loop rodando
        loop = asyncio.get_event_loop()
        loop.create_task(main())
# Out:
# C:\Users\Luan Lima\AppData\Local\Temp\ipykernel_23192\2276111983.py:33: RuntimeWarning: coroutine 'main' was never awaited
#   loop.create_task(main())
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# {'Nome': 'Alice', 'Idade': 25}
# {'Nome': 'Bob', 'Idade': 30}
# {'Nome': 'Carlos', 'Idade': 22}

# %%
import asyncio

async def minha_funcao(i):
    await asyncio.sleep(1)
    print(f"Tarefa {i} concluída")

async def main():
    tarefas = [asyncio.create_task(minha_funcao(i)) for i in range(1000)]
    await asyncio.gather(*tarefas)

asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 11
#       8     tarefas = [asyncio.create_task(minha_funcao(i)) for i in range(1000)]
#       9     await asyncio.gather(*tarefas)
# ---> 11 asyncio.run(main())
#
# File c:\Users\Luan Lima\AppData\Local\Programs\Python\Python310\lib\asyncio\runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import asyncio

async def minha_funcao(i, sem):
    async with sem:
        await asyncio.sleep(1)
        print(f"Tarefa {i} concluída")

async def main():
    sem = asyncio.Semaphore(10)  # Limita para 10 tarefas simultâneas
    tarefas = [asyncio.create_task(minha_funcao(i, sem)) for i in range(1000)]
    await asyncio.gather(*tarefas)

# Verifica se o loop está rodando, caso não, executa com asyncio.run()
try:
    asyncio.get_event_loop().run_until_complete(main())
except RuntimeError:  # Isso acontece se o loop não estiver em execução
    asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 15
#      14 try:
# ---> 15     asyncio.get_event_loop().run_until_complete(main())
#      16 except RuntimeError:  # Isso acontece se o loop não estiver em execução
#
# File c:\Users\Luan Lima\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py:622, in BaseEventLoop.run_until_complete(self, future)
#     621 self._check_closed()
# --> 622 self._check_running()
#     624 new_task = not futures.isfuture(future)
#
# File c:\Users\Luan Lima\AppData\Local\Programs\Python\Python310\lib\asyncio\base_events.py:582, in BaseEventLoop._check_running(self)
#     581 if self.is_running():
# --> 582     raise RuntimeError('This event loop is already running')
#     583 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 17
#      15     asyncio.get_event_loop().run_until_complete(main())
#      16 except RuntimeError:  # Isso acontece se o loop não estiver em execução
# ---> 17     asyncio.run(main())
#
# File c:\Users\Luan Lima\AppData\Local\Programs\Python\Python310\lib\asyncio\runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import asyncio

async def minha_funcao(i, sem):
    async with sem:
        await asyncio.sleep(1)
        print(f"Tarefa {i} concluída")

async def main():
    sem = asyncio.Semaphore(100)  # Limita para 10 tarefas simultâneas
    tarefas = [asyncio.create_task(minha_funcao(i, sem)) for i in range(1000)]
    await asyncio.gather(*tarefas)

# No Jupyter Notebook ou ambiente interativo, simplesmente use `await` para rodar a função principal
await main()
# Out:
# Tarefa 0 concluída
# Tarefa 2 concluída
# Tarefa 6 concluída
# Tarefa 14 concluída
# Tarefa 30 concluída
# Tarefa 62 concluída
# Tarefa 99 concluída
# Tarefa 98 concluída
# Tarefa 97 concluída
# Tarefa 96 concluída
# Tarefa 95 concluída
# Tarefa 94 concluída
# Tarefa 93 concluída
# Tarefa 92 concluída
# Tarefa 91 concluída
# Tarefa 90 concluída
# Tarefa 89 concluída
# Tarefa 88 concluída
# Tarefa 87 concluída
# Tarefa 86 concluída
# Tarefa 85 concluída
# Tarefa 84 concluída
# Tarefa 83 concluída
# Tarefa 82 concluída
# Tarefa 81 concluída
# Tarefa 80 concluída
# Tarefa 79 concluída
# Tarefa 78 concluída
# Tarefa 77 concluída
# Tarefa 76 concluída
# Tarefa 75 concluída
# Tarefa 74 concluída
# Tarefa 73 concluída
# Tarefa 72 concluída
# Tarefa 71 concluída
# Tarefa 70 concluída
# Tarefa 69 concluída
# Tarefa 68 concluída
# Tarefa 67 concluída
# Tarefa 66 concluída
# Tarefa 65 concluída
# Tarefa 64 concluída
# Tarefa 61 concluída
# Tarefa 63 concluída
# Tarefa 60 concluída
# Tarefa 59 concluída
# Tarefa 58 concluída
# Tarefa 57 concluída
# Tarefa 56 concluída
# Tarefa 55 concluída
# Tarefa 54 concluída
# Tarefa 53 concluída
# Tarefa 52 concluída
# Tarefa 51 concluída
# Tarefa 50 concluída
# Tarefa 49 concluída
# Tarefa 48 concluída
# Tarefa 47 concluída
# Tarefa 46 concluída
# Tarefa 45 concluída
# Tarefa 44 concluída
# Tarefa 43 concluída
# Tarefa 42 concluída
# Tarefa 41 concluída
# Tarefa 40 concluída
# Tarefa 39 concluída
# Tarefa 38 concluída
# Tarefa 37 concluída
# Tarefa 36 concluída
# Tarefa 35 concluída
# Tarefa 34 concluída
# Tarefa 33 concluída
# Tarefa 32 concluída
# Tarefa 29 concluída
# Tarefa 31 concluída
# Tarefa 28 concluída
# Tarefa 27 concluída
# Tarefa 26 concluída
# Tarefa 25 concluída
# Tarefa 24 concluída
# Tarefa 23 concluída
# Tarefa 22 concluída
# Tarefa 21 concluída
# Tarefa 20 concluída
# Tarefa 19 concluída
# Tarefa 18 concluída
# Tarefa 17 concluída
# Tarefa 16 concluída
# Tarefa 13 concluída
# Tarefa 15 concluída
# Tarefa 12 concluída
# Tarefa 11 concluída
# Tarefa 10 concluída
# Tarefa 9 concluída
# Tarefa 8 concluída
# Tarefa 5 concluída
# Tarefa 7 concluída
# Tarefa 4 concluída
# Tarefa 1 concluída
# Tarefa 3 concluída
# Tarefa 100 concluída
# Tarefa 102 concluída
# Tarefa 106 concluída
# Tarefa 114 concluída
# Tarefa 130 concluída
# Tarefa 162 concluída
# Tarefa 199 concluída
# Tarefa 198 concluída
# Tarefa 197 concluída
# Tarefa 196 concluída
# Tarefa 195 concluída
# Tarefa 194 concluída
# Tarefa 193 concluída
# Tarefa 192 concluída
# Tarefa 191 concluída
# Tarefa 190 concluída
# Tarefa 189 concluída
# Tarefa 188 concluída
# Tarefa 187 concluída
# Tarefa 186 concluída
# Tarefa 185 concluída
# Tarefa 184 concluída
# Tarefa 183 concluída
# Tarefa 182 concluída
# Tarefa 181 concluída
# Tarefa 180 concluída
# Tarefa 179 concluída
# Tarefa 178 concluída
# Tarefa 177 concluída
# Tarefa 176 concluída
# Tarefa 175 concluída
# Tarefa 174 concluída
# Tarefa 173 concluída
# Tarefa 172 concluída
# Tarefa 171 concluída
# Tarefa 170 concluída
# Tarefa 169 concluída
# Tarefa 168 concluída
# Tarefa 167 concluída
# Tarefa 166 concluída
# Tarefa 165 concluída
# Tarefa 164 concluída
# Tarefa 161 concluída
# Tarefa 163 concluída
# Tarefa 160 concluída
# Tarefa 159 concluída
# Tarefa 158 concluída
# Tarefa 157 concluída
# Tarefa 156 concluída
# Tarefa 155 concluída
# Tarefa 154 concluída
# Tarefa 153 concluída
# Tarefa 152 concluída
# Tarefa 151 concluída
# Tarefa 150 concluída
# Tarefa 149 concluída
# Tarefa 148 concluída
# Tarefa 147 concluída
# Tarefa 146 concluída
# Tarefa 145 concluída
# Tarefa 144 concluída
# Tarefa 143 concluída
# Tarefa 142 concluída
# Tarefa 141 concluída
# Tarefa 140 concluída
# Tarefa 139 concluída
# Tarefa 138 concluída
# Tarefa 137 concluída
# Tarefa 136 concluída
# Tarefa 135 concluída
# Tarefa 134 concluída
# Tarefa 133 concluída
# Tarefa 132 concluída
# Tarefa 129 concluída
# Tarefa 131 concluída
# Tarefa 128 concluída
# Tarefa 127 concluída
# Tarefa 126 concluída
# Tarefa 125 concluída
# Tarefa 124 concluída
# Tarefa 123 concluída
# Tarefa 122 concluída
# Tarefa 121 concluída
# Tarefa 120 concluída
# Tarefa 119 concluída
# Tarefa 118 concluída
# Tarefa 117 concluída
# Tarefa 116 concluída
# Tarefa 113 concluída
# Tarefa 115 concluída
# Tarefa 112 concluída
# Tarefa 111 concluída
# Tarefa 110 concluída
# Tarefa 109 concluída
# Tarefa 108 concluída
# Tarefa 105 concluída
# Tarefa 107 concluída
# Tarefa 104 concluída
# Tarefa 101 concluída
# Tarefa 103 concluída
# Tarefa 200 concluída
# Tarefa 202 concluída
# Tarefa 206 concluída
# Tarefa 214 concluída
# Tarefa 230 concluída
# Tarefa 262 concluída
# Tarefa 299 concluída
# Tarefa 298 concluída
# Tarefa 297 concluída
# Tarefa 296 concluída
# Tarefa 295 concluída
# Tarefa 294 concluída
# Tarefa 293 concluída
# Tarefa 292 concluída
# Tarefa 291 concluída
# Tarefa 290 concluída
# Tarefa 289 concluída
# Tarefa 288 concluída
# Tarefa 287 concluída
# Tarefa 286 concluída
# Tarefa 285 concluída
# Tarefa 284 concluída
# Tarefa 283 concluída
# Tarefa 282 concluída
# Tarefa 281 concluída
# Tarefa 280 concluída
# Tarefa 279 concluída
# Tarefa 278 concluída
# Tarefa 277 concluída
# Tarefa 276 concluída
# Tarefa 275 concluída
# Tarefa 274 concluída
# Tarefa 273 concluída
# Tarefa 272 concluída
# Tarefa 271 concluída
# Tarefa 270 concluída
# Tarefa 269 concluída
# Tarefa 268 concluída
# Tarefa 267 concluída
# Tarefa 266 concluída
# Tarefa 265 concluída
# Tarefa 264 concluída
# Tarefa 261 concluída
# Tarefa 263 concluída
# Tarefa 260 concluída
# Tarefa 259 concluída
# Tarefa 258 concluída
# Tarefa 257 concluída
# Tarefa 256 concluída
# Tarefa 255 concluída
# Tarefa 254 concluída
# Tarefa 253 concluída
# Tarefa 252 concluída
# Tarefa 251 concluída
# Tarefa 250 concluída
# Tarefa 249 concluída
# Tarefa 248 concluída
# Tarefa 247 concluída
# Tarefa 246 concluída
# Tarefa 245 concluída
# Tarefa 244 concluída
# Tarefa 243 concluída
# Tarefa 242 concluída
# Tarefa 241 concluída
# Tarefa 240 concluída
# Tarefa 239 concluída
# Tarefa 238 concluída
# Tarefa 237 concluída
# Tarefa 236 concluída
# Tarefa 235 concluída
# Tarefa 234 concluída
# Tarefa 233 concluída
# Tarefa 232 concluída
# Tarefa 229 concluída
# Tarefa 231 concluída
# Tarefa 228 concluída
# Tarefa 227 concluída
# Tarefa 226 concluída
# Tarefa 225 concluída
# Tarefa 224 concluída
# Tarefa 223 concluída
# Tarefa 222 concluída
# Tarefa 221 concluída
# Tarefa 220 concluída
# Tarefa 219 concluída
# Tarefa 218 concluída
# Tarefa 217 concluída
# Tarefa 216 concluída
# Tarefa 213 concluída
# Tarefa 215 concluída
# Tarefa 212 concluída
# Tarefa 211 concluída
# Tarefa 210 concluída
# Tarefa 209 concluída
# Tarefa 208 concluída
# Tarefa 205 concluída
# Tarefa 207 concluída
# Tarefa 204 concluída
# Tarefa 201 concluída
# Tarefa 203 concluída
# Tarefa 300 concluída
# Tarefa 302 concluída
# Tarefa 306 concluída
# Tarefa 314 concluída
# Tarefa 330 concluída
# Tarefa 362 concluída
# Tarefa 399 concluída
# Tarefa 398 concluída
# Tarefa 397 concluída
# Tarefa 396 concluída
# Tarefa 395 concluída
# Tarefa 394 concluída
# Tarefa 393 concluída
# Tarefa 392 concluída
# Tarefa 391 concluída
# Tarefa 390 concluída
# Tarefa 389 concluída
# Tarefa 388 concluída
# Tarefa 387 concluída
# Tarefa 386 concluída
# Tarefa 385 concluída
# Tarefa 384 concluída
# Tarefa 383 concluída
# Tarefa 382 concluída
# Tarefa 381 concluída
# Tarefa 380 concluída
# Tarefa 379 concluída
# Tarefa 378 concluída
# Tarefa 377 concluída
# Tarefa 376 concluída
# Tarefa 375 concluída
# Tarefa 374 concluída
# Tarefa 373 concluída
# Tarefa 372 concluída
# Tarefa 371 concluída
# Tarefa 370 concluída
# Tarefa 369 concluída
# Tarefa 368 concluída
# Tarefa 367 concluída
# Tarefa 366 concluída
# Tarefa 365 concluída
# Tarefa 364 concluída
# Tarefa 361 concluída
# Tarefa 363 concluída
# Tarefa 360 concluída
# Tarefa 359 concluída
# Tarefa 358 concluída
# Tarefa 357 concluída
# Tarefa 356 concluída
# Tarefa 355 concluída
# Tarefa 354 concluída
# Tarefa 353 concluída
# Tarefa 352 concluída
# Tarefa 351 concluída
# Tarefa 350 concluída
# Tarefa 349 concluída
# Tarefa 348 concluída
# Tarefa 347 concluída
# Tarefa 346 concluída
# Tarefa 345 concluída
# Tarefa 344 concluída
# Tarefa 343 concluída
# Tarefa 342 concluída
# Tarefa 341 concluída
# Tarefa 340 concluída
# Tarefa 339 concluída
# Tarefa 338 concluída
# Tarefa 337 concluída
# Tarefa 336 concluída
# Tarefa 335 concluída
# Tarefa 334 concluída
# Tarefa 333 concluída
# Tarefa 332 concluída
# Tarefa 329 concluída
# Tarefa 331 concluída
# Tarefa 328 concluída
# Tarefa 327 concluída
# Tarefa 326 concluída
# Tarefa 325 concluída
# Tarefa 324 concluída
# Tarefa 323 concluída
# Tarefa 322 concluída
# Tarefa 321 concluída
# Tarefa 320 concluída
# Tarefa 319 concluída
# Tarefa 318 concluída
# Tarefa 317 concluída
# Tarefa 316 concluída
# Tarefa 313 concluída
# Tarefa 315 concluída
# Tarefa 312 concluída
# Tarefa 311 concluída
# Tarefa 310 concluída
# Tarefa 309 concluída
# Tarefa 308 concluída
# Tarefa 305 concluída
# Tarefa 307 concluída
# Tarefa 304 concluída
# Tarefa 301 concluída
# Tarefa 303 concluída
# Tarefa 400 concluída
# Tarefa 402 concluída
# Tarefa 406 concluída
# Tarefa 414 concluída
# Tarefa 430 concluída
# Tarefa 462 concluída
# Tarefa 499 concluída
# Tarefa 498 concluída
# Tarefa 497 concluída
# Tarefa 496 concluída
# Tarefa 495 concluída
# Tarefa 494 concluída
# Tarefa 493 concluída
# Tarefa 492 concluída
# Tarefa 491 concluída
# Tarefa 490 concluída
# Tarefa 489 concluída
# Tarefa 488 concluída
# Tarefa 487 concluída
# Tarefa 486 concluída
# Tarefa 485 concluída
# Tarefa 484 concluída
# Tarefa 483 concluída
# Tarefa 482 concluída
# Tarefa 481 concluída
# Tarefa 480 concluída
# Tarefa 479 concluída
# Tarefa 478 concluída
# Tarefa 477 concluída
# Tarefa 476 concluída
# Tarefa 475 concluída
# Tarefa 474 concluída
# Tarefa 473 concluída
# Tarefa 472 concluída
# Tarefa 471 concluída
# Tarefa 470 concluída
# Tarefa 469 concluída
# Tarefa 468 concluída
# Tarefa 467 concluída
# Tarefa 466 concluída
# Tarefa 465 concluída
# Tarefa 464 concluída
# Tarefa 461 concluída
# Tarefa 463 concluída
# Tarefa 460 concluída
# Tarefa 459 concluída
# Tarefa 458 concluída
# Tarefa 457 concluída
# Tarefa 456 concluída
# Tarefa 455 concluída
# Tarefa 454 concluída
# Tarefa 453 concluída
# Tarefa 452 concluída
# Tarefa 451 concluída
# Tarefa 450 concluída
# Tarefa 449 concluída
# Tarefa 448 concluída
# Tarefa 447 concluída
# Tarefa 446 concluída
# Tarefa 445 concluída
# Tarefa 444 concluída
# Tarefa 443 concluída
# Tarefa 442 concluída
# Tarefa 441 concluída
# Tarefa 440 concluída
# Tarefa 439 concluída
# Tarefa 438 concluída
# Tarefa 437 concluída
# Tarefa 436 concluída
# Tarefa 435 concluída
# Tarefa 434 concluída
# Tarefa 433 concluída
# Tarefa 432 concluída
# Tarefa 429 concluída
# Tarefa 431 concluída
# Tarefa 428 concluída
# Tarefa 427 concluída
# Tarefa 426 concluída
# Tarefa 425 concluída
# Tarefa 424 concluída
# Tarefa 423 concluída
# Tarefa 422 concluída
# Tarefa 421 concluída
# Tarefa 420 concluída
# Tarefa 419 concluída
# Tarefa 418 concluída
# Tarefa 417 concluída
# Tarefa 416 concluída
# Tarefa 413 concluída
# Tarefa 415 concluída
# Tarefa 412 concluída
# Tarefa 411 concluída
# Tarefa 410 concluída
# Tarefa 409 concluída
# Tarefa 408 concluída
# Tarefa 405 concluída
# Tarefa 407 concluída
# Tarefa 404 concluída
# Tarefa 401 concluída
# Tarefa 403 concluída
# Tarefa 500 concluída
# Tarefa 502 concluída
# Tarefa 506 concluída
# Tarefa 514 concluída
# Tarefa 530 concluída
# Tarefa 529 concluída
# Tarefa 513 concluída
# Tarefa 528 concluída
# Tarefa 527 concluída
# Tarefa 505 concluída
# Tarefa 512 concluída
# Tarefa 526 concluída
# Tarefa 525 concluída
# Tarefa 511 concluída
# Tarefa 524 concluída
# Tarefa 523 concluída
# Tarefa 501 concluída
# Tarefa 504 concluída
# Tarefa 510 concluída
# Tarefa 522 concluída
# Tarefa 521 concluída
# Tarefa 509 concluída
# Tarefa 520 concluída
# Tarefa 519 concluída
# Tarefa 503 concluída
# Tarefa 508 concluída
# Tarefa 518 concluída
# Tarefa 517 concluída
# Tarefa 535 concluída
# Tarefa 507 concluída
# Tarefa 516 concluída
# Tarefa 534 concluída
# Tarefa 533 concluída
# Tarefa 515 concluída
# Tarefa 532 concluída
# Tarefa 531 concluída
# Tarefa 562 concluída
# Tarefa 599 concluída
# Tarefa 597 concluída
# Tarefa 593 concluída
# Tarefa 585 concluída
# Tarefa 569 concluída
# Tarefa 561 concluída
# Tarefa 560 concluída
# Tarefa 598 concluída
# Tarefa 559 concluída
# Tarefa 558 concluída
# Tarefa 596 concluída
# Tarefa 594 concluída
# Tarefa 557 concluída
# Tarefa 556 concluída
# Tarefa 595 concluída
# Tarefa 555 concluída
# Tarefa 554 concluída
# Tarefa 592 concluída
# Tarefa 590 concluída
# Tarefa 586 concluída
# Tarefa 553 concluída
# Tarefa 552 concluída
# Tarefa 591 concluída
# Tarefa 551 concluída
# Tarefa 550 concluída
# Tarefa 589 concluída
# Tarefa 587 concluída
# Tarefa 549 concluída
# Tarefa 548 concluída
# Tarefa 588 concluída
# Tarefa 547 concluída
# Tarefa 546 concluída
# Tarefa 584 concluída
# Tarefa 582 concluída
# Tarefa 578 concluída
# Tarefa 565 concluída
# Tarefa 545 concluída
# Tarefa 544 concluída
# Tarefa 583 concluída
# Tarefa 543 concluída
# Tarefa 563 concluída
# Tarefa 542 concluída
# Tarefa 581 concluída
# Tarefa 579 concluída
# Tarefa 541 concluída
# Tarefa 540 concluída
# Tarefa 580 concluída
# Tarefa 539 concluída
# Tarefa 538 concluída
# Tarefa 577 concluída
# Tarefa 575 concluída
# Tarefa 576 concluída
# Tarefa 537 concluída
# Tarefa 536 concluída
# Tarefa 574 concluída
# Tarefa 572 concluída
# Tarefa 570 concluída
# Tarefa 573 concluída
# Tarefa 567 concluída
# Tarefa 568 concluída
# Tarefa 566 concluída
# Tarefa 571 concluída
# Tarefa 564 concluída
# Tarefa 635 concluída
# Tarefa 633 concluída
# Tarefa 629 concluída
# Tarefa 621 concluída
# Tarefa 609 concluída
# Tarefa 632 concluída
# Tarefa 628 concluída
# Tarefa 626 concluída
# Tarefa 625 concluída
# Tarefa 620 concluída
# Tarefa 618 concluída
# Tarefa 614 concluída
# Tarefa 617 concluída
# Tarefa 613 concluída
# Tarefa 611 concluída
# Tarefa 610 concluída
# Tarefa 604 concluída
# Tarefa 602 concluída
# Tarefa 634 concluída
# Tarefa 619 concluída
# Tarefa 601 concluída
# Tarefa 630 concluída
# Tarefa 622 concluída
# Tarefa 627 concluída
# Tarefa 615 concluída
# Tarefa 607 concluída
# Tarefa 616 concluída
# Tarefa 612 concluída
# Tarefa 608 concluída
# Tarefa 603 concluída
# Tarefa 600 concluída
# Tarefa 623 concluída
# Tarefa 605 concluída
# Tarefa 606 concluída
# Tarefa 624 concluída
# Tarefa 631 concluída
# Tarefa 662 concluída
# Tarefa 699 concluída
# Tarefa 697 concluída
# Tarefa 693 concluída
# Tarefa 685 concluída
# Tarefa 669 concluída
# Tarefa 661 concluída
# Tarefa 660 concluída
# Tarefa 698 concluída
# Tarefa 659 concluída
# Tarefa 658 concluída
# Tarefa 696 concluída
# Tarefa 694 concluída
# Tarefa 657 concluída
# Tarefa 656 concluída
# Tarefa 695 concluída
# Tarefa 655 concluída
# Tarefa 654 concluída
# Tarefa 692 concluída
# Tarefa 690 concluída
# Tarefa 686 concluída
# Tarefa 653 concluída
# Tarefa 652 concluída
# Tarefa 691 concluída
# Tarefa 651 concluída
# Tarefa 650 concluída
# Tarefa 689 concluída
# Tarefa 687 concluída
# Tarefa 649 concluída
# Tarefa 648 concluída
# Tarefa 688 concluída
# Tarefa 647 concluída
# Tarefa 646 concluída
# Tarefa 684 concluída
# Tarefa 682 concluída
# Tarefa 678 concluída
# Tarefa 665 concluída
# Tarefa 645 concluída
# Tarefa 644 concluída
# Tarefa 683 concluída
# Tarefa 643 concluída
# Tarefa 663 concluída
# Tarefa 642 concluída
# Tarefa 681 concluída
# Tarefa 679 concluída
# Tarefa 641 concluída
# Tarefa 640 concluída
# Tarefa 680 concluída
# Tarefa 639 concluída
# Tarefa 638 concluída
# Tarefa 677 concluída
# Tarefa 675 concluída
# Tarefa 676 concluída
# Tarefa 637 concluída
# Tarefa 636 concluída
# Tarefa 674 concluída
# Tarefa 672 concluída
# Tarefa 670 concluída
# Tarefa 673 concluída
# Tarefa 667 concluída
# Tarefa 668 concluída
# Tarefa 666 concluída
# Tarefa 671 concluída
# Tarefa 664 concluída
# Tarefa 735 concluída
# Tarefa 733 concluída
# Tarefa 729 concluída
# Tarefa 721 concluída
# Tarefa 709 concluída
# Tarefa 732 concluída
# Tarefa 728 concluída
# Tarefa 726 concluída
# Tarefa 725 concluída
# Tarefa 720 concluída
# Tarefa 718 concluída
# Tarefa 714 concluída
# Tarefa 717 concluída
# Tarefa 713 concluída
# Tarefa 711 concluída
# Tarefa 710 concluída
# Tarefa 704 concluída
# Tarefa 702 concluída
# Tarefa 734 concluída
# Tarefa 719 concluída
# Tarefa 701 concluída
# Tarefa 730 concluída
# Tarefa 722 concluída
# Tarefa 727 concluída
# Tarefa 715 concluída
# Tarefa 707 concluída
# Tarefa 716 concluída
# Tarefa 712 concluída
# Tarefa 708 concluída
# Tarefa 703 concluída
# Tarefa 700 concluída
# Tarefa 723 concluída
# Tarefa 705 concluída
# Tarefa 706 concluída
# Tarefa 724 concluída
# Tarefa 731 concluída
# Tarefa 762 concluída
# Tarefa 799 concluída
# Tarefa 797 concluída
# Tarefa 793 concluída
# Tarefa 785 concluída
# Tarefa 769 concluída
# Tarefa 761 concluída
# Tarefa 760 concluída
# Tarefa 798 concluída
# Tarefa 759 concluída
# Tarefa 758 concluída
# Tarefa 796 concluída
# Tarefa 794 concluída
# Tarefa 757 concluída
# Tarefa 756 concluída
# Tarefa 795 concluída
# Tarefa 755 concluída
# Tarefa 754 concluída
# Tarefa 792 concluída
# Tarefa 790 concluída
# Tarefa 786 concluída
# Tarefa 753 concluída
# Tarefa 752 concluída
# Tarefa 791 concluída
# Tarefa 751 concluída
# Tarefa 750 concluída
# Tarefa 789 concluída
# Tarefa 787 concluída
# Tarefa 749 concluída
# Tarefa 748 concluída
# Tarefa 788 concluída
# Tarefa 747 concluída
# Tarefa 746 concluída
# Tarefa 784 concluída
# Tarefa 782 concluída
# Tarefa 778 concluída
# Tarefa 765 concluída
# Tarefa 745 concluída
# Tarefa 744 concluída
# Tarefa 783 concluída
# Tarefa 743 concluída
# Tarefa 763 concluída
# Tarefa 742 concluída
# Tarefa 781 concluída
# Tarefa 779 concluída
# Tarefa 741 concluída
# Tarefa 740 concluída
# Tarefa 780 concluída
# Tarefa 739 concluída
# Tarefa 738 concluída
# Tarefa 777 concluída
# Tarefa 775 concluída
# Tarefa 776 concluída
# Tarefa 737 concluída
# Tarefa 736 concluída
# Tarefa 774 concluída
# Tarefa 772 concluída
# Tarefa 770 concluída
# Tarefa 773 concluída
# Tarefa 767 concluída
# Tarefa 768 concluída
# Tarefa 766 concluída
# Tarefa 771 concluída
# Tarefa 764 concluída
# Tarefa 835 concluída
# Tarefa 833 concluída
# Tarefa 829 concluída
# Tarefa 821 concluída
# Tarefa 809 concluída
# Tarefa 832 concluída
# Tarefa 828 concluída
# Tarefa 826 concluída
# Tarefa 825 concluída
# Tarefa 820 concluída
# Tarefa 818 concluída
# Tarefa 814 concluída
# Tarefa 817 concluída
# Tarefa 813 concluída
# Tarefa 811 concluída
# Tarefa 810 concluída
# Tarefa 804 concluída
# Tarefa 802 concluída
# Tarefa 834 concluída
# Tarefa 819 concluída
# Tarefa 801 concluída
# Tarefa 830 concluída
# Tarefa 822 concluída
# Tarefa 827 concluída
# Tarefa 815 concluída
# Tarefa 807 concluída
# Tarefa 816 concluída
# Tarefa 812 concluída
# Tarefa 808 concluída
# Tarefa 803 concluída
# Tarefa 800 concluída
# Tarefa 823 concluída
# Tarefa 805 concluída
# Tarefa 806 concluída
# Tarefa 824 concluída
# Tarefa 831 concluída
# Tarefa 862 concluída
# Tarefa 899 concluída
# Tarefa 897 concluída
# Tarefa 893 concluída
# Tarefa 885 concluída
# Tarefa 869 concluída
# Tarefa 861 concluída
# Tarefa 860 concluída
# Tarefa 898 concluída
# Tarefa 859 concluída
# Tarefa 858 concluída
# Tarefa 896 concluída
# Tarefa 894 concluída
# Tarefa 857 concluída
# Tarefa 856 concluída
# Tarefa 895 concluída
# Tarefa 855 concluída
# Tarefa 854 concluída
# Tarefa 892 concluída
# Tarefa 890 concluída
# Tarefa 886 concluída
# Tarefa 853 concluída
# Tarefa 852 concluída
# Tarefa 891 concluída
# Tarefa 851 concluída
# Tarefa 850 concluída
# Tarefa 889 concluída
# Tarefa 887 concluída
# Tarefa 849 concluída
# Tarefa 848 concluída
# Tarefa 888 concluída
# Tarefa 847 concluída
# Tarefa 846 concluída
# Tarefa 884 concluída
# Tarefa 882 concluída
# Tarefa 878 concluída
# Tarefa 865 concluída
# Tarefa 845 concluída
# Tarefa 844 concluída
# Tarefa 883 concluída
# Tarefa 843 concluída
# Tarefa 863 concluída
# Tarefa 842 concluída
# Tarefa 881 concluída
# Tarefa 879 concluída
# Tarefa 841 concluída
# Tarefa 840 concluída
# Tarefa 880 concluída
# Tarefa 839 concluída
# Tarefa 838 concluída
# Tarefa 877 concluída
# Tarefa 875 concluída
# Tarefa 876 concluída
# Tarefa 837 concluída
# Tarefa 836 concluída
# Tarefa 874 concluída
# Tarefa 872 concluída
# Tarefa 870 concluída
# Tarefa 873 concluída
# Tarefa 867 concluída
# Tarefa 868 concluída
# Tarefa 866 concluída
# Tarefa 871 concluída
# Tarefa 864 concluída
# Tarefa 935 concluída
# Tarefa 933 concluída
# Tarefa 929 concluída
# Tarefa 921 concluída
# Tarefa 909 concluída
# Tarefa 932 concluída
# Tarefa 928 concluída
# Tarefa 926 concluída
# Tarefa 925 concluída
# Tarefa 920 concluída
# Tarefa 918 concluída
# Tarefa 914 concluída
# Tarefa 917 concluída
# Tarefa 913 concluída
# Tarefa 911 concluída
# Tarefa 910 concluída
# Tarefa 904 concluída
# Tarefa 902 concluída
# Tarefa 934 concluída
# Tarefa 919 concluída
# Tarefa 901 concluída
# Tarefa 930 concluída
# Tarefa 922 concluída
# Tarefa 927 concluída
# Tarefa 915 concluída
# Tarefa 907 concluída
# Tarefa 916 concluída
# Tarefa 912 concluída
# Tarefa 908 concluída
# Tarefa 903 concluída
# Tarefa 900 concluída
# Tarefa 923 concluída
# Tarefa 905 concluída
# Tarefa 906 concluída
# Tarefa 924 concluída
# Tarefa 931 concluída
# Tarefa 962 concluída
# Tarefa 999 concluída
# Tarefa 997 concluída
# Tarefa 993 concluída
# Tarefa 985 concluída
# Tarefa 969 concluída
# Tarefa 961 concluída
# Tarefa 963 concluída
# Tarefa 998 concluída
# Tarefa 959 concluída
# Tarefa 994 concluída
# Tarefa 957 concluída
# Tarefa 995 concluída
# Tarefa 955 concluída
# Tarefa 986 concluída
# Tarefa 953 concluída
# Tarefa 991 concluída
# Tarefa 951 concluída
# Tarefa 987 concluída
# Tarefa 949 concluída
# Tarefa 988 concluída
# Tarefa 947 concluída
# Tarefa 965 concluída
# Tarefa 945 concluída
# Tarefa 983 concluída
# Tarefa 943 concluída
# Tarefa 979 concluída
# Tarefa 941 concluída
# Tarefa 980 concluída
# Tarefa 939 concluída
# Tarefa 976 concluída
# Tarefa 937 concluída
# Tarefa 974 concluída
# Tarefa 972 concluída
# Tarefa 967 concluída
# Tarefa 968 concluída
# Tarefa 971 concluída
# Tarefa 960 concluída
# Tarefa 964 concluída
# Tarefa 996 concluída
# Tarefa 956 concluída
# Tarefa 990 concluída
# Tarefa 952 concluída
# Tarefa 989 concluída
# Tarefa 948 concluída
# Tarefa 978 concluída
# Tarefa 944 concluída
# Tarefa 981 concluída
# Tarefa 940 concluída
# Tarefa 975 concluída
# Tarefa 936 concluída
# Tarefa 973 concluída
# Tarefa 958 concluída
# Tarefa 966 concluída
# Tarefa 992 concluída
# Tarefa 950 concluída
# Tarefa 982 concluída
# Tarefa 942 concluída
# Tarefa 977 concluída
# Tarefa 954 concluída
# Tarefa 970 concluída
# Tarefa 984 concluída
# Tarefa 946 concluída
# Tarefa 938 concluída

# %%
# Criando um DataFrame de exemplo
dados = {'Nome': ['Alice', 'Bob', 'Carlos'], 'Idade': [25, 30, 22]}
df = pd.DataFrame(dados)

# %%
df
# Out:
#      Nome  Idade
# 0   Alice     25
# 1     Bob     30
# 2  Carlos     22

# %%
'Alice'	'Bob'	 'Carlos'

# %%
df[df['Nome'] == 'Alice']['Idade'][0]
# Out:
# 25

# %%
import asyncio

# Função assíncrona que será chamada dentro de 'minha_funcao'
async def outra_funcao(df, i):
    await asyncio.sleep(0.5)  # Simula um tempo de espera
    j = df.loc[df['Nome'] == i].reset_index()
    j = j['Idade'][0]
    print(f"Idade {j}")

# Função principal que será chamada nas tarefas
async def minha_funcao(df, i, sem):
    async with sem:
        await outra_funcao(df, i)  # Chama a outra função assíncrona
        await asyncio.sleep(1)
        print(f"Tarefa {i} concluída")

# Função que organiza a execução das tarefas
async def main():
    lista = ['Alice','Bob','Carlos','Alice','Bob','Carlos', 'Alice','Bob','Carlos']  # Sua lista de itens para iterar
    dados = {'Nome': ['Alice', 'Bob', 'Carlos'], 'Idade': [25, 30, 22]}
    df = pd.DataFrame(dados)

    sem = asyncio.Semaphore(1000)  # Limita a 10 tarefas simultâneas

    # Criar e executar as tarefas em paralelo
    tarefas = [asyncio.create_task(minha_funcao(df, i, sem)) for i in lista]
    await asyncio.gather(*tarefas)

# No Jupyter Notebook ou ambiente interativo, basta usar `await` para rodar a função principal
await main()
# Out:
# Idade 25
# Idade 22
# Idade 25
# Idade 22
# Idade 22
# Idade 30
# Idade 30
# Idade 30
# Idade 25
# Tarefa Alice concluída
# Tarefa Alice concluída
# Tarefa Carlos concluída
# Tarefa Carlos concluída
# Tarefa Bob concluída
# Tarefa Bob concluída
# Tarefa Alice concluída
# Tarefa Carlos concluída
# Tarefa Bob concluída

# %%
import asyncio

# Função assíncrona que será chamada dentro de 'minha_funcao'
async def outra_funcao(i):
    await asyncio.sleep(0.5)  # Simula um tempo de espera
    print(f"Outra tarefa {i} concluída")

# Função principal que será chamada nas tarefas
async def minha_funcao(i, sem):
    async with sem:
        await outra_funcao(i)  # Chama a outra função assíncrona
        await asyncio.sleep(10)
        print(f"Tarefa {i} concluída")

# Função que organiza a execução das tarefas
async def main():
    lista = [ 'Jão']  # Sua lista de itens para iterar
    sem = asyncio.Semaphore(1000)  # Limita a 10 tarefas simultâneas

    # Criar e executar as tarefas em paralelo
    tarefas = [asyncio.create_task(minha_funcao(i, sem)) for i in lista]
    await asyncio.gather(*tarefas)

# No Jupyter Notebook ou ambiente interativo, basta usar `await` para rodar a função principal
await main()
