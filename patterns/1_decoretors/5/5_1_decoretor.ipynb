# %% [markdown]
# ✅ 1. @abstractmethod (você já viu)
# 📌 Serve para:
#
# Obrigar subclasses a implementar o método.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def speak(self):
        pass

# %% [markdown]
# Se uma classe herdar e não implementar → ERRO.

# %% [markdown]
# ✅ 2. @property
# 📌 Serve para:
#
# Transformar um método em atributo acessível sem parênteses.
#
# Sem @property

# %%
class Person:
    def get_name(self):
        return "Luan"

# %%
Person().get_name()
# Out:
# 'Luan'

# %% [markdown]
# Com @property

# %%
class Person:
    @property
    def name(self):
        return "Luan"

# %%
Person().name
# Out:
# 'Luan'

# %% [markdown]
# ✅ 3. @staticmethod
# 📌 Serve para:
#
# Criar método que não usa self nem a classe.
#
# Exemplo:

# %%
class Math:

    @staticmethod
    def add(a, b):
        return a + b

# %%
Math.add(2, 3)
# Out:
# 5

# %% [markdown]
# ✅ 4. @classmethod
# 📌 Serve para:
#
# Método que recebe a classe como parâmetro, não a instância.
#
# Usa cls em vez de self.
#
# Exemplo:

# %%
class Person:

    total = 0

    def __init__(self):
        Person.total += 1

    @classmethod
    def count(cls):
        return cls.total

# %%
Person.count()
# Out:
# 0

# %% [markdown]
# ✅ 5. @dataclass
#
# Muito usado hoje.
#
# 📌 Serve para:
#
# Criar classes automaticamente sem escrever __init__.
#
# Exemplo:

# %%
from dataclasses import dataclass

@dataclass
class User:
    name: str
    age: int

# %% [markdown]
# Python cria automaticamente:
#
# init
#
# repr
#
# eq
#
# ✅ 6. @final
# 📌 Serve para:
#
# Indicar que a classe ou método não deve ser sobrescrito.
#
# (Usado principalmente em tipagem)

# %%
from typing import final

@final
class Car:
    passß

# %% [markdown]
# ✅ 7. @override (Python 3.12+)
# 📌 Serve para:
#
# Indicar que um método está sobrescrevendo outro.
#
# Ajuda a evitar erros.
#
# 🧠 Outras palavras “especiais” importantes (não são decoradores)
# 🔹 super()
#
# Chama método da classe pai.

# %%
super().__init__()

# %% [markdown]
# 🔹 self
#
# Representa a instância atual.
#
# 🔹 cls
#
# Representa a classe.
#
# 🔹 ABC
#
# Define classe abstrata.
